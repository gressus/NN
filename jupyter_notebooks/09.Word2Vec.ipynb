# %% [markdown]
# <a href="https://colab.research.google.com/github/gressus/NN/blob/main/jupyter_notebooks/09.Word2Vec.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <a href="https://colab.research.google.com/github/minsuk-heo/tf2/blob/master/jupyter_notebooks/09.Word2Vec.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import tensorflow_hub as hub
import numpy as np

# %%
# Load Pretrained Word2Vec
embed = hub.load("https://tfhub.dev/google/Wiki-words-250-with-normalization/2")

# %%
words = ["coffee", "cafe", "Coffeehouse", "Bistro", "Cafeteria", "football", "soccer", "Tearoom", "Diner", "Eatery", "Brasserie", "Canteen", "Coffee shop", "Espresso bar", "cat", "dog"]

# Compute embeddings.
embeddings = embed(words)

# %%
print(embeddings.shape)
# Out:
# (16, 250)

# %%
print(embeddings[0])
# Out:
# tf.Tensor(
# [-0.02354056 -0.08136939 -0.09588724  0.04267474 -0.03513853  0.09099629
#  -0.01959137 -0.07235982 -0.04527646 -0.02064468 -0.05868183  0.05026427
#   0.08757452 -0.02868579 -0.00528093 -0.07107743 -0.00430126 -0.1111517
#  -0.0371297  -0.07397588  0.01366727  0.04489887  0.10918173 -0.00385636
#  -0.00768068 -0.12602517  0.0073157   0.0887766  -0.06376575 -0.02794223
#   0.07697963 -0.00691205 -0.05405519 -0.11509552  0.02446181 -0.01677185
#  -0.07807938 -0.05697621 -0.08125712 -0.08814868 -0.08236694 -0.08067547
#   0.0609058  -0.03083544 -0.03890334 -0.04752342  0.05156425  0.06546737
#  -0.00422008 -0.05087236  0.00757163 -0.05662974 -0.02225585  0.09144896
#   0.01537593 -0.03186006 -0.07453508 -0.09245355 -0.0335355  -0.02733024
#  -0.09283264  0.07827969  0.01312644  0.01702355  0.03512271 -0.06434979
#  -0.07367618  0.02042403 -0.09727054 -0.02774223  0.09928335  0.06212646
#   0.09546035 -0.04408428 -0.00725705 -0.00057283 -0.0287641   0.03661085
#  -0.05806859 -0.05408818  0.0231409  -0.07298388  0.1646798   0.07809006
#  -0.01111982  0.14087161 -0.04396361  0.04126683  0.02877898  0.01905746
#   0.1105309   0.06654984 -0.00078718 -0.09800068  0.07190014 -0.131704
#  -0.03441447 -0.02738335  0.03093908 -0.01418934  0.04429242 -0.01806876
#   0.04542694 -0.05444206 -0.08348989 -0.05099544  0.04747298  0.06506849
#  -0.05768571 -0.00440776  0.01051272 -0.08287345  0.11204316 -0.05460041
#   0.00567209 -0.07521604  0.11076885 -0.04829612  0.05183472 -0.04895689
#  -0.02137397  0.02561938 -0.05885033  0.04311425 -0.07235826 -0.09585836
#  -0.03546391  0.00806308 -0.0619843   0.05591873 -0.08550402 -0.08185065
#  -0.05578732 -0.09064139 -0.01335919 -0.07727531  0.02775419 -0.08254696
#   0.04840679  0.02586558  0.00663981 -0.06776338 -0.07152627  0.01210419
#  -0.00852732 -0.01058301 -0.1619424   0.02026587 -0.01388948  0.00189575
#   0.03454833  0.05086273  0.03521772 -0.03332255 -0.00988645  0.02418481
#   0.05226289  0.02611434  0.10866518  0.05978051 -0.08198778 -0.02986844
#  -0.06233634  0.10071989 -0.03119567 -0.11822581  0.01693426 -0.0608105
#  -0.05698326 -0.10583136 -0.13607931  0.02407905 -0.03629255  0.02076313
#  -0.04213256 -0.06741277 -0.06263477  0.04730252  0.03838075  0.10238209
#  -0.07200056 -0.0440848   0.01331067 -0.00238228  0.03103796 -0.05993534
#   0.05239792 -0.04665108 -0.04364431 -0.00259019  0.00851675  0.02730579
#   0.07337386  0.01205894 -0.00536067 -0.02512251  0.0261053  -0.0362059
#   0.03148042 -0.07700469 -0.05770168 -0.13220859  0.01733035 -0.16073275
#   0.02587633  0.0902601   0.05141979 -0.02696803  0.02988728  0.03869817
#  -0.11350647 -0.02808783  0.02539633 -0.13162673 -0.05006778 -0.00478651
#  -0.05001132 -0.08984482  0.01518493 -0.03974978  0.07634825  0.01875645
#  -0.00474618  0.01459583 -0.04914725 -0.00623341 -0.02581113  0.01803032
#   0.09076595  0.02429139 -0.02663588 -0.1329482  -0.00831683  0.12574844
#  -0.21781795  0.07475684 -0.06326763 -0.06678488  0.03054501 -0.04050571
#   0.00973472 -0.06373728  0.1009348  -0.03326001  0.02156528 -0.02337086
#  -0.00653275  0.03182182 -0.05427     0.02559574], shape=(250,), dtype=float32)

# %%
# Compute similarity matrix. Higher score indicates greater similarity.
for i in range(len(words)):
    for j in range(i,len(words)):
        print("(",words[i], ",", words[j],")",np.inner(embeddings[i], embeddings[j]))
# Out:
# ( coffee , coffee ) 1.0
# ( coffee , cafe ) 0.5485246
# ( coffee , Coffeehouse ) 0.30511943
# ( coffee , Bistro ) 0.42468917
# ( coffee , Cafeteria ) 0.3054957
# ( coffee , football ) -0.0049367556
# ( coffee , soccer ) 0.03198619
# ( coffee , Tearoom ) 0.3204768
# ( coffee , Diner ) 0.39720085
# ( coffee , Eatery ) 0.43811372
# ( coffee , Brasserie ) 0.3782427
# ( coffee , Canteen ) 0.2604071
# ( coffee , Coffee shop ) 0.8937446
# ( coffee , Espresso bar ) 0.45410785
# ( coffee , cat ) 0.1760905
# ( coffee , dog ) 0.21386923
# ( cafe , cafe ) 1.0
# ( cafe , Coffeehouse ) 0.48695132
# ( cafe , Bistro ) 0.6806274
# ( cafe , Cafeteria ) 0.58244926
# ( cafe , football ) 0.0658585
# ( cafe , soccer ) 0.15623057
# ( cafe , Tearoom ) 0.46529305
# ( cafe , Diner ) 0.6003653
# ( cafe , Eatery ) 0.6237197
# ( cafe , Brasserie ) 0.50978506
# ( cafe , Canteen ) 0.54604864
# ( cafe , Coffee shop ) 0.9105591
# ( cafe , Espresso bar ) 0.43423343
# ( cafe , cat ) 0.21920681
# ( cafe , dog ) 0.25762683
# ( Coffeehouse , Coffeehouse ) 1.0
# ( Coffeehouse , Bistro ) 0.5402827
# ( Coffeehouse , Cafeteria ) 0.4768769
# ( Coffeehouse , football ) 0.038112428
# ( Coffeehouse , soccer ) 0.09281897
# ( Coffeehouse , Tearoom ) 0.34485745
# ( Coffeehouse , Diner ) 0.4999088
# ( Coffeehouse , Eatery ) 0.50203496
# ( Coffeehouse , Brasserie ) 0.3626508
# ( Coffeehouse , Canteen ) 0.4506051
# ( Coffeehouse , Coffee shop ) 0.63532925
# ( Coffeehouse , Espresso bar ) 0.36445034
# ( Coffeehouse , cat ) 0.003391578
# ( Coffeehouse , dog ) 0.024207762
# ( Bistro , Bistro ) 1.0
# ( Bistro , Cafeteria ) 0.58953035
# ( Bistro , football ) -0.007781488
# ( Bistro , soccer ) 0.07543924
# ( Bistro , Tearoom ) 0.34293196
# ( Bistro , Diner ) 0.65916574
# ( Bistro , Eatery ) 0.78548646
# ( Bistro , Brasserie ) 0.70190567
# ( Bistro , Canteen ) 0.5113054
# ( Bistro , Coffee shop ) 0.8090977
# ( Bistro , Espresso bar ) 0.48053676
# ( Bistro , cat ) 0.099205546
# ( Bistro , dog ) 0.10110536
# ( Cafeteria , Cafeteria ) 1.0
# ( Cafeteria , football ) -0.017487457
# ( Cafeteria , soccer ) 0.12891652
# ( Cafeteria , Tearoom ) 0.41627994
# ( Cafeteria , Diner ) 0.50980943
# ( Cafeteria , Eatery ) 0.5692494
# ( Cafeteria , Brasserie ) 0.3501736
# ( Cafeteria , Canteen ) 0.6526957
# ( Cafeteria , Coffee shop ) 0.63741785
# ( Cafeteria , Espresso bar ) 0.31229556
# ( Cafeteria , cat ) 0.059165735
# ( Cafeteria , dog ) 0.056791168
# ( football , football ) 1.0
# ( football , soccer ) 0.7606856
# ( football , Tearoom ) -0.11203742
# ( football , Diner ) -0.06307719
# ( football , Eatery ) 0.017505502
# ( football , Brasserie ) 0.025269955
# ( football , Canteen ) 0.039827842
# ( football , Coffee shop ) 0.043145366
# ( football , Espresso bar ) -0.029526185
# ( football , cat ) -0.12490998
# ( football , dog ) -0.0065341117
# ( soccer , soccer ) 1.0
# ( soccer , Tearoom ) -0.07871001
# ( soccer , Diner ) 0.021285316
# ( soccer , Eatery ) 0.07494479
# ( soccer , Brasserie ) 0.02826751
# ( soccer , Canteen ) 0.06407362
# ( soccer , Coffee shop ) 0.07292451
# ( soccer , Espresso bar ) 0.040714175
# ( soccer , cat ) -0.054507807
# ( soccer , dog ) 0.05571916
# ( Tearoom , Tearoom ) 1.0000001
# ( Tearoom , Diner ) 0.36625394
# ( Tearoom , Eatery ) 0.3939485
# ( Tearoom , Brasserie ) 0.29895195
# ( Tearoom , Canteen ) 0.3579393
# ( Tearoom , Coffee shop ) 0.57294226
# ( Tearoom , Espresso bar ) 0.24046716
# ( Tearoom , cat ) 0.16113894
# ( Tearoom , dog ) 0.19029905
# ( Diner , Diner ) 1.0
# ( Diner , Eatery ) 0.6754517
# ( Diner , Brasserie ) 0.43031725
# ( Diner , Canteen ) 0.4976031
# ( Diner , Coffee shop ) 0.7914078
# ( Diner , Espresso bar ) 0.35229135
# ( Diner , cat ) 0.2659129
# ( Diner , dog ) 0.2618323
# ( Eatery , Eatery ) 1.0
# ( Eatery , Brasserie ) 0.6409048
# ( Eatery , Canteen ) 0.47659677
# ( Eatery , Coffee shop ) 0.7948066
# ( Eatery , Espresso bar ) 0.45653674
# ( Eatery , cat ) 0.15067433
# ( Eatery , dog ) 0.14710979
# ( Brasserie , Brasserie ) 1.0
# ( Brasserie , Canteen ) 0.2936275
# ( Brasserie , Coffee shop ) 0.6194567
# ( Brasserie , Espresso bar ) 0.4045733
# ( Brasserie , cat ) 0.0057804896
# ( Brasserie , dog ) -0.005913079
# ( Canteen , Canteen ) 0.99999994
# ( Canteen , Coffee shop ) 0.6472625
# ( Canteen , Espresso bar ) 0.23126583
# ( Canteen , cat ) 0.07833529
# ( Canteen , dog ) 0.12249462
# ( Coffee shop , Coffee shop ) 1.5143069
# ( Coffee shop , Espresso bar ) 0.62602985
# ( Coffee shop , cat ) 0.1591809
# ( Coffee shop , dog ) 0.26316342
# ( Espresso bar , Espresso bar ) 1.0964633
# ( Espresso bar , cat ) 0.08135818
# ( Espresso bar , dog ) 0.056056384
# ( cat , cat ) 1.0
# ( cat , dog ) 0.8490828
# ( dog , dog ) 1.0

# %%
from scipy.spatial.distance import cosine

for i in range(len(words)):
    for j in range(i,len(words)):
        cosine_similarity = 1 - cosine(embeddings[i], embeddings[j])
        print("(", words[i], ",", words[j], ")", cosine_similarity)
# Out:
# ( coffee , coffee ) 1
# ( coffee , cafe ) 0.5485245585441589
# ( coffee , Coffeehouse ) 0.30511942505836487
# ( coffee , Bistro ) 0.4246891140937805
# ( coffee , Cafeteria ) 0.3054957389831543
# ( coffee , football ) -0.0049367621541023254
# ( coffee , soccer ) 0.03198617696762085
# ( coffee , Tearoom ) 0.320476770401001
# ( coffee , Diner ) 0.3972008228302002
# ( coffee , Eatery ) 0.4381136894226074
# ( coffee , Brasserie ) 0.3782426416873932
# ( coffee , Canteen ) 0.26040706038475037
# ( coffee , Coffee shop ) 0.7262839078903198
# ( coffee , Espresso bar ) 0.43367257714271545
# ( coffee , cat ) 0.17609050869941711
# ( coffee , dog ) 0.21386924386024475
# ( cafe , cafe ) 1
# ( cafe , Coffeehouse ) 0.4869512617588043
# ( cafe , Bistro ) 0.6806274056434631
# ( cafe , Cafeteria ) 0.5824492573738098
# ( cafe , football ) 0.06585849821567535
# ( cafe , soccer ) 0.15623056888580322
# ( cafe , Tearoom ) 0.4652930498123169
# ( cafe , Diner ) 0.6003652811050415
# ( cafe , Eatery ) 0.6237196922302246
# ( cafe , Brasserie ) 0.5097850561141968
# ( cafe , Canteen ) 0.5460485816001892
# ( cafe , Coffee shop ) 0.7399479746818542
# ( cafe , Espresso bar ) 0.4146924912929535
# ( cafe , cat ) 0.2192068248987198
# ( cafe , dog ) 0.25762683153152466
# ( Coffeehouse , Coffeehouse ) 1
# ( Coffeehouse , Bistro ) 0.5402827262878418
# ( Coffeehouse , Cafeteria ) 0.4768769145011902
# ( Coffeehouse , football ) 0.038112424314022064
# ( Coffeehouse , soccer ) 0.0928189679980278
# ( Coffeehouse , Tearoom ) 0.34485745429992676
# ( Coffeehouse , Diner ) 0.4999087452888489
# ( Coffeehouse , Eatery ) 0.5020350217819214
# ( Coffeehouse , Brasserie ) 0.3626507818698883
# ( Coffeehouse , Canteen ) 0.4506051242351532
# ( Coffeehouse , Coffee shop ) 0.5162878036499023
# ( Coffeehouse , Espresso bar ) 0.34804975986480713
# ( Coffeehouse , cat ) 0.0033915804233402014
# ( Coffeehouse , dog ) 0.02420775778591633
# ( Bistro , Bistro ) 1
# ( Bistro , Cafeteria ) 0.5895302891731262
# ( Bistro , football ) -0.00778148602694273
# ( Bistro , soccer ) 0.07543924450874329
# ( Bistro , Tearoom ) 0.34293195605278015
# ( Bistro , Diner ) 0.6591656804084778
# ( Bistro , Eatery ) 0.7854865193367004
# ( Bistro , Brasserie ) 0.7019057273864746
# ( Bistro , Canteen ) 0.5113053917884827
# ( Bistro , Coffee shop ) 0.6574973464012146
# ( Bistro , Espresso bar ) 0.45891210436820984
# ( Bistro , cat ) 0.09920553117990494
# ( Bistro , dog ) 0.10110536217689514
# ( Cafeteria , Cafeteria ) 1
# ( Cafeteria , football ) -0.017487453296780586
# ( Cafeteria , soccer ) 0.12891650199890137
# ( Cafeteria , Tearoom ) 0.41627994179725647
# ( Cafeteria , Diner ) 0.5098094344139099
# ( Cafeteria , Eatery ) 0.5692493319511414
# ( Cafeteria , Brasserie ) 0.35017356276512146
# ( Cafeteria , Canteen ) 0.6526957154273987
# ( Cafeteria , Coffee shop ) 0.5179850459098816
# ( Cafeteria , Espresso bar ) 0.2982419729232788
# ( Cafeteria , cat ) 0.059165727347135544
# ( Cafeteria , dog ) 0.056791145354509354
# ( football , football ) 1
# ( football , soccer ) 0.7606855034828186
# ( football , Tearoom ) -0.11203740537166595
# ( football , Diner ) -0.0630771815776825
# ( football , Eatery ) 0.017505502328276634
# ( football , Brasserie ) 0.02526996098458767
# ( football , Canteen ) 0.03982784226536751
# ( football , Coffee shop ) 0.03506123274564743
# ( football , Espresso bar ) -0.028197478502988815
# ( football , cat ) -0.12490998208522797
# ( football , dog ) -0.0065341065637767315
# ( soccer , soccer ) 1
# ( soccer , Tearoom ) -0.07871000468730927
# ( soccer , Diner ) 0.021285319700837135
# ( soccer , Eatery ) 0.07494477927684784
# ( soccer , Brasserie ) 0.028267497196793556
# ( soccer , Canteen ) 0.06407362222671509
# ( soccer , Coffee shop ) 0.05926065891981125
# ( soccer , Espresso bar ) 0.03888199105858803
# ( soccer , cat ) -0.054507818073034286
# ( soccer , dog ) 0.05571917071938515
# ( Tearoom , Tearoom ) 1
# ( Tearoom , Diner ) 0.36625394225120544
# ( Tearoom , Eatery ) 0.3939485251903534
# ( Tearoom , Brasserie ) 0.29895198345184326
# ( Tearoom , Canteen ) 0.35793930292129517
# ( Tearoom , Coffee shop ) 0.465590238571167
# ( Tearoom , Espresso bar ) 0.22964589297771454
# ( Tearoom , cat ) 0.16113892197608948
# ( Tearoom , dog ) 0.19029901921749115
# ( Diner , Diner ) 1
# ( Diner , Eatery ) 0.6754517555236816
# ( Diner , Brasserie ) 0.4303172528743744
# ( Diner , Canteen ) 0.49760305881500244
# ( Diner , Coffee shop ) 0.6431219577789307
# ( Diner , Espresso bar ) 0.3364378809928894
# ( Diner , cat ) 0.26591283082962036
# ( Diner , dog ) 0.26183226704597473
# ( Eatery , Eatery ) 1
# ( Eatery , Brasserie ) 0.6409047245979309
# ( Eatery , Canteen ) 0.4765967130661011
# ( Eatery , Coffee shop ) 0.6458839178085327
# ( Eatery , Espresso bar ) 0.43599218130111694
# ( Eatery , cat ) 0.15067434310913086
# ( Eatery , dog ) 0.14710979163646698
# ( Brasserie , Brasserie ) 1
# ( Brasserie , Canteen ) 0.29362753033638
# ( Brasserie , Coffee shop ) 0.5033893585205078
# ( Brasserie , Espresso bar ) 0.38636717200279236
# ( Brasserie , cat ) 0.005780499428510666
# ( Brasserie , dog ) -0.00591308856382966
# ( Canteen , Canteen ) 1
# ( Canteen , Coffee shop ) 0.5259851217269897
# ( Canteen , Espresso bar ) 0.22085867822170258
# ( Canteen , cat ) 0.07833530753850937
# ( Canteen , dog ) 0.12249460816383362
# ( Coffee shop , Coffee shop ) 1
# ( Coffee shop , Espresso bar ) 0.48583748936653137
# ( Coffee shop , cat ) 0.12935523688793182
# ( Coffee shop , dog ) 0.21385458111763
# ( Espresso bar , Espresso bar ) 1
# ( Espresso bar , cat ) 0.07769698649644852
# ( Espresso bar , dog ) 0.05353379622101784
# ( cat , cat ) 1
# ( cat , dog ) 0.8490827679634094
# ( dog , dog ) 1

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Assume words and embeddings are defined

# Initialize a zero matrix
similarity_matrix = np.zeros((len(words), len(words)))

# Compute similarity matrix. Higher score indicates greater similarity.
for i in range(len(words)):
    for j in range(i, len(words)):
        similarity = np.inner(embeddings[i], embeddings[j])
        similarity_matrix[i, j] = similarity
        similarity_matrix[j, i] = similarity  # The matrix is symmetric

plt.figure(figsize=(12, 9))  # Increase figure size
sns.heatmap(similarity_matrix, annot=True, xticklabels=words, yticklabels=words)

plt.show()

# %%
# Compute t-SNE with a smaller perplexity
tsne = TSNE(n_components=2, perplexity=len(words) - 1, random_state=42)  # assuming you have more than 10 word embeddings
embeddings_2d = tsne.fit_transform(embeddings)

# Plot the result
plt.figure(figsize=(10, 10))
for i, word in enumerate(words):
    x, y = embeddings_2d[i, :]
    plt.scatter(x, y)
    plt.annotate(word, xy=(x, y), xytext=(5, 2), textcoords='offset points', ha='right', va='bottom')

plt.show()

# %%
from sklearn.decomposition import PCA

# Compute PCA
pca = PCA(n_components=2)
embeddings_2d = pca.fit_transform(embeddings)

# Plot the result
plt.figure(figsize=(10, 10))
for i, word in enumerate(words):
    x, y = embeddings_2d[i, :]
    plt.scatter(x, y)
    plt.annotate(word, xy=(x, y), xytext=(5, 2), textcoords='offset points', ha='right', va='bottom')

plt.show()
